# %%
import pandas as pd

monthly = pd.read_csv('hs_monthly.csv', dtype={'commodity': str})
monthly['REF_DATE'] = pd.to_datetime(monthly['REF_DATE'])

print('Shape:', monthly.shape)
print()
print('Columns:', monthly.columns.tolist())
print()
print('First 5 rows:')
print(monthly.head())
print()
print('One commodity in isolation (e.g. steel 7208):')
df = monthly[monthly['commodity'] == '7208'].sort_values('REF_DATE')
print(df.head(15))
# Out:
# Shape: (5244, 3)
#
# Columns: ['REF_DATE', 'commodity', 'VALUE']
#
# First 5 rows:
#     REF_DATE commodity       VALUE
# 0 2015-01-01      0302    50910411
# 1 2015-01-01      0303     7813575
# 2 2015-01-01      0304    22338246
# 3 2015-01-01      0305     4477108
# 4 2015-01-01      2709  6705658347
#
# One commodity in isolation (e.g. steel 7208):
#       REF_DATE commodity     VALUE
# 8   2015-01-01      7208  85763899
# 46  2015-02-01      7208  62936875
# 84  2015-03-01      7208  75062068
# 122 2015-04-01      7208  65007434
# 160 2015-05-01      7208  69672350
# 198 2015-06-01      7208  77703366
# 236 2015-07-01      7208  80681737
# 274 2015-08-01      7208  81512028
# 312 2015-09-01      7208  78572804
# 350 2015-10-01      7208  60706435
# 388 2015-11-01      7208  57861190
# 426 2015-12-01      7208  60237802
# 464 2016-01-01      7208  81942306
# 502 2016-02-01      7208  70017062
# 540 2016-03-01      7208  67932443
